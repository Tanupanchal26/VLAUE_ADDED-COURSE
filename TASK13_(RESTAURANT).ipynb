# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanupanchal26/VLAUE_ADDED-COURSE/blob/main/TASK13_(RESTAURANT).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
df = pd.read_csv('/content/restaurant.csv', encoding='latin1')
df.head()
# Out:
#    Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0           0       16.99  1.01  Female     No  Sun  Dinner     2
# 1           1       10.34  1.66    Male     No  Sun  Dinner     3
# 2           2       21.01  3.50    Male     No  Sun  Dinner     3
# 3           3       23.68  3.31    Male     No  Sun  Dinner     2
# 4           4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df.tail()
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.shape
# Out:
# (244, 8)

# %%
df.head()
# Out:
#    Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0           0       16.99  1.01  Female     No  Sun  Dinner     2
# 1           1       10.34  1.66    Male     No  Sun  Dinner     3
# 2           2       21.01  3.50    Male     No  Sun  Dinner     3
# 3           3       23.68  3.31    Male     No  Sun  Dinner     2
# 4           4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.sample(2)
# Out:
#      Unnamed: 0  total_bill   tip   sex smoker  day    time  size
# 23           23       39.42  7.58  Male     No  Sat  Dinner     4
# 190         190       15.69  1.50  Male    Yes  Sun  Dinner     2

# %%
df.describe()
# Out:
#        Unnamed: 0  total_bill         tip        size
# count  244.000000  244.000000  244.000000  244.000000
# mean   121.500000   19.785943    2.998279    2.569672
# std     70.580923    8.902412    1.383638    0.951100
# min      0.000000    3.070000    1.000000    1.000000
# 25%     60.750000   13.347500    2.000000    2.000000
# 50%    121.500000   17.795000    2.900000    2.000000
# 75%    182.250000   24.127500    3.562500    3.000000
# max    243.000000   50.810000   10.000000    6.000000

# %%
df.isnull()
# Out:
#      Unnamed: 0  total_bill    tip    sex  smoker    day   time   size
# 0         False       False  False  False   False  False  False  False
# 1         False       False  False  False   False  False  False  False
# 2         False       False  False  False   False  False  False  False
# 3         False       False  False  False   False  False  False  False
# 4         False       False  False  False   False  False  False  False
# ..          ...         ...    ...    ...     ...    ...    ...    ...
# 239       False       False  False  False   False  False  False  False
# 240       False       False  False  False   False  False  False  False
# 241       False       False  False  False   False  False  False  False
# 242       False       False  False  False   False  False  False  False
# 243       False       False  False  False   False  False  False  False
#
# [244 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df['smoker'].dtype
# Out:
# dtype('O')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'total_bill', 'tip', 'sex', 'smoker', 'day', 'time',
#        'size'],
#       dtype='object')

# %%
df.rename(columns={'day':'weekday'})
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker weekday    time  size
# 0             0       16.99  1.01  Female     No     Sun  Dinner     2
# 1             1       10.34  1.66    Male     No     Sun  Dinner     3
# 2             2       21.01  3.50    Male     No     Sun  Dinner     3
# 3             3       23.68  3.31    Male     No     Sun  Dinner     2
# 4             4       24.59  3.61  Female     No     Sun  Dinner     4
# ..          ...         ...   ...     ...    ...     ...     ...   ...
# 239         239       29.03  5.92    Male     No     Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes     Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes     Sat  Dinner     2
# 242         242       17.82  1.75    Male     No     Sat  Dinner     2
# 243         243       18.78  3.00  Female     No    Thur  Dinner     2
#
# [244 rows x 8 columns]

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 0             0       16.99  1.01  Female     No   Sun  Dinner     2
# 1             1       10.34  1.66    Male     No   Sun  Dinner     3
# 2             2       21.01  3.50    Male     No   Sun  Dinner     3
# 3             3       23.68  3.31    Male     No   Sun  Dinner     2
# 4             4       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]>

# %%
df[['smoker','time']].describe()
# Out:
#        smoker    time
# count     244     244
# unique      2       2
# top        No  Dinner
# freq      151     176

# %%
ax=sns.countplot(x='sex',data=df)
for bars in ax.containers:
  ax.bar_label(bars)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.figure(figsize=(10,6))

ax=sns.countplot(x='sex',data=df,palette='cool',edgecolor='black')

# Add title and labels
ax.set_title("sex Distribution", fontsize=14, fontweight='bold')
ax.set_xlabel("sex", fontsize=12)
ax.set_ylabel("Count", fontsize=12)

# Add data labels on bars
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}',
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom', fontsize=10)

sns.despine()
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_772/3347130669.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x='sex',data=df,palette='cool',edgecolor='black')

# %%
sales_gen = df.groupby(['sex'], as_index=False)['total_bill'].sum().sort_values (by='total_bill', ascending=False)

sns.barplot(x = 'sex', y= 'total_bill', data = sales_gen)
plt.show()

# %% [markdown]
# From above graphs we can see that male customers contribute a higher total bill amount than female customers.

# %%
ax = sns.countplot(
    data=df,x="sex", hue="sex", palette={"Female": "pink", "Male": "blue"},edgecolor='black')

plt.show()

# %%
 # Total Amount vs Age Group

sales_age = df.groupby(['sex'], as_index=False)['total_bill'].sum().sort_values(by='total_bill', ascending=False)
sns.barplot(x = 'sex', y= 'total_bill', data = sales_age)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# From above graphs we can see that  male buyers have higher total spending than
# female buyers.

# %%
orders_state = df.groupby(['day'], as_index=False)['total_bill'].sum()\
                 .sort_values(by='total_bill', ascending=False).head(5)
sns.set(rc={'figure.figsize':(10,4)})

ax = sns.barplot(x='day', y='total_bill', data=orders_state, palette='rocket')

plt.title("Top Days by Total Bill", fontsize=14, fontweight='bold')
plt.xlabel("Day", fontsize=12)
plt.ylabel("Total Bill", fontsize=12)
plt.xticks(rotation=60)

# Add labels
for bars in ax.containers:
    ax.bar_label(bars)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_772/783816695.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='day', y='total_bill', data=orders_state, palette='rocket')

# %%
sales_state = df.groupby (['day'], as_index=False) ["total_bill"].sum().sort_values (by='total_bill', ascending=False).head(10)

sns.set(rc={'figure.figsize': (15,5)})

sns.barplot(data = sales_state, x = 'day', y= 'total_bill')

plt.xticks(rotation=30)
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'Sat'), Text(1, 0, 'Sun'), Text(2, 0, 'Thur'), Text(3, 0, 'Fri')])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid", rc={'figure.figsize': (8,4)})

ax = sns.histplot(data=df, x='tip', bins=20, kde=True, color='skyblue', edgecolor='black')

plt.title("Distribution of Tips", fontsize=12, fontweight='bold')
plt.xlabel("Tip Amount")
plt.ylabel("Count")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create tip_round column
df['tip_round'] = df['tip'].round()

sales_state = df.groupby(['tip_round', 'sex'], as_index=False)['total_bill'].sum() \
                .sort_values(by='total_bill', ascending=False)

sns.set(style="whitegrid", rc={'figure.figsize': (8,5)})

ax = sns.barplot(
    data=sales_state,
    x='tip_round',
    y='total_bill',
    hue='sex',
    palette='deep'
)

plt.title("Total Bill by Tip and Gender", fontsize=13, fontweight='bold')
plt.xlabel("Tip Amount")
plt.ylabel("Total Bill")

# Add labels
for container in ax.containers:
    ax.bar_label(container, fmt='%.0f')

plt.tight_layout()
plt.show()

# %% [markdown]
# From above graphs we can see that ale customers have higher total spending than female customers across different tip amounts.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(rc={'figure.figsize': (10,5)})

ax = sns.countplot(data=df, x='sex')

for bars in ax.containers:
    ax.bar_label(bars)
plt.xticks(rotation=60)
plt.show()

# %%
sns.set(rc={'figure.figsize': (10,5)})

ax = sns.countplot(data =df, x = 'size')
plt.xticks(rotation = 45)
plt.grid(1)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = df.groupby(['size'], as_index=False)['total_bill'].sum().sort_values(by='total_bill', ascending=False).head(10)

sns.set(rc={'figure.figsize': (10,5)})

sns.barplot(data=sales_state, x='size', y='total_bill')
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sales_state = df.groupby(['sex'], as_index=False).size().sort_values(by='size', ascending=False)

sns.set(rc={'figure.figsize': (6,4)})
ax = sns.barplot(data=sales_state, x='sex', y='size', palette='cool')

# Add labels
for bars in ax.containers:
    ax.bar_label(bars)

plt.xlabel("Gender")
plt.ylabel("Count")
plt.title("Gender Distribution")

plt.show()
# Out:
# /tmp/ipykernel_772/636031617.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=sales_state, x='sex', y='size', palette='cool')

# %%
import matplotlib.pyplot as plt

fig1, ax1 = plt.subplots(figsize=(12,7))

df['total_bill'].value_counts().head(10).plot(kind='bar')

plt.xlabel("Total Bill")
plt.ylabel("Count")

plt.show()

# %% [markdown]
# # Conclusion:
#
# Most of the total revenue is generated during dinner time, with male customers contributing slightly higher total bills, particularly on weekends and for larger group sizes.
