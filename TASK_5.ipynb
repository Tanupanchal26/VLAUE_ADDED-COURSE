# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanupanchal26/VLAUE_ADDED-COURSE/blob/main/TASK_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fruits = ["apple", "banana", "cherry"]
print("List:", fruits)
# Out:
# List: ['apple', 'banana', 'cherry']

# %%
fruits = ["apple", "banana", "cherry"]
print("First element:", fruits[0])
print("Last element:", fruits[-1])
# Out:
# First element: apple
# Last element: cherry

# %%
fruits = ["apple", "banana", "cherry"]
print("Sliced list:", fruits[0:2])
# Out:
# Sliced list: ['apple', 'banana']

# %%
fruits = ["apple", "banana", "cherry","watermelon","strawberry"]
sublist_fruits=fruits[:2]
print("sublist of first three fruits",sublist_fruits)
# Out:
# sublist of first three fruits ['apple', 'banana']

# %%
fruits = ["apple", "banana", "cherry","watermelon","strawberry"]
fruits.append("orange")
print("After append:", fruits)
# Out:
# After append: ['apple', 'banana', 'cherry', 'watermelon', 'strawberry', 'orange']

# %%
fruits = ["apple", "banana", "cherry","watermelon","strawberry"]
fruits.insert(1, "mango")
print("After insert:", fruits)
# Out:
# After insert: ['apple', 'mango', 'banana', 'cherry', 'watermelon', 'strawberry']

# %%
fruits = ["apple", "banana", "cherry","watermelon","strawberry"]
fruits.remove("banana")
print("After remove:", fruits)
# Out:
# After remove: ['apple', 'cherry', 'watermelon', 'strawberry']

# %%
fruits = ["apple", "banana", "cherry","watermelon","strawberry"]
popped = fruits.pop()
print("Popped:", popped)
print("After pop:", fruits)
# Out:
# Popped: strawberry
# After pop: ['apple', 'banana', 'cherry', 'watermelon']

# %%
fruits = ["apple", "banana", "cherry","watermelon","strawberry"]
print("Length:", len(fruits))
# Out:
# Length: 5

# %%
fruits = ["apple", "banana", "cherry","watermelon","strawberry"]
print("apple in list?", "apple" in fruits)
# Out:
# apple in list? True

# %%
fruits = ["apple", "banana", "cherry","watermelon","strawberry"]
print("Iterating list:")
for fruit in fruits:
    print(fruit)
# Out:
# Iterating list:
# apple
# banana
# cherry
# watermelon
# strawberry

# %%
fruits = ["apple", "banana", "cherry","watermelon","strawberry"]
fruits.sort()
print("Sorted list:", fruits)
# Out:
# Sorted list: ['apple', 'banana', 'cherry', 'strawberry', 'watermelon']

# %%
fruits = ["apple", "banana", "cherry","watermelon","strawberry"]
fruits.reverse()
print("Reversed list:", fruits)
# Out:
# Reversed list: ['strawberry', 'watermelon', 'cherry', 'banana', 'apple']

# %%
fruits = ["apple", "banana", "cherry","watermelon","strawberry"]
new_list = [x.upper() for x in fruits]
print("List comprehension:", new_list)
# Out:
# List comprehension: ['APPLE', 'BANANA', 'CHERRY', 'WATERMELON', 'STRAWBERRY']

# %%
fruits = ["apple", "banana", "cherry","watermelon","strawberry"]
copy_list = fruits.copy()
print("Copied list:", copy_list)
# Out:
# Copied list: ['apple', 'banana', 'cherry', 'watermelon', 'strawberry']

# %%
fruits = ["apple", "banana", "cherry","watermelon","strawberry"]
temp = fruits.copy()
temp.clear()
print("Cleared list:", temp)
# Out:
# Cleared list: []

# %%
fruits = ["apple", "banana", "cherry","watermelon","strawberry"]
more_fruits = ["grape", "pineapple"]
fruits.extend(more_fruits)
print("Extended list:", fruits)
# Out:
# Extended list: ['apple', 'banana', 'cherry', 'watermelon', 'strawberry', 'grape', 'pineapple']

# %%
fruits = ["apple", "banana", "cherry","watermelon","strawberry"]
print("Count of apple:", fruits.count("apple"))
# Out:
# Count of apple: 1

# %%
fruits = ["apple", "banana", "cherry","watermelon","strawberry"]
print("Index of apple:", fruits.index("apple"))
# Out:
# Index of apple: 0

# %%
fruits = ["apple", "banana", "cherry","watermelon","strawberry"]
del fruits[0]
print("After deleting index 0:", fruits)
# Out:
# After deleting index 0: ['banana', 'cherry', 'watermelon', 'strawberry']

# %%
fruits = ["apple", "banana", "cherry","watermelon","strawberry"]
nested_list = [["apple", "banana"], ["cherry", "mango"]]
print("Nested list:", nested_list)
print("Access nested element:", nested_list[0][1])
# Out:
# Nested list: [['apple', 'banana'], ['cherry', 'mango']]
# Access nested element: banana
