# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanupanchal26/VLAUE_ADDED-COURSE/blob/main/TASK_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text = "hello world"
result = text.capitalize()

print(result)  # Hello world
# Out:
# Hello world

# %%
text = "Python"
result = text.center(20, "-")

print(result)  # -------Python-------
# Out:
# -------Python-------

# %%
text = "HELLO WORLD"
result = text.casefold()

print(result)  # hello world
# Out:
# hello world

# %%
text = "banana"
result = text.count("a")

print(result)  # 3
# Out:
# 3

# %%
text = "hello.py"
result = text.endswith(".py")

print(result)  # True
# Out:
# True

# %%
text = "H\te\tl\tl\to"
result = text.expandtabs(4)

print(result)
# Out:
# H   e   l   l   o

# %%
text = "hello"
result = text.encode()

print(result)  # b'hello'
# Out:
# b'hello'

# %%
text = "hello world"
result = text.find("world")

print(result)  # 6
# Out:
# 6

# %%
name = "John"
age = 25

result = "My name is {} and I am {} years old".format(name, age)

print(result)
# Out:
# My name is John and I am 25 years old

# %%
text = "hello world"
result = text.index("world")

print(result)  # 6
# Out:
# 6

# %%
text = "Python123"
result = text.isalnum()

print(result)  # True
# Out:
# True

# %%
text = "Python"
result = text.isalpha()

print(result)  # True
# Out:
# True

# %%
text = "12345"
result = text.isdecimal()

print(result)  # True
# Out:
# True

# %%
text = "12345"
result = text.isdigit()

print(result)  # True
# Out:
# True

# %%
text = "my_variable"
result = text.isidentifier()

print(result)  # True
# Out:
# True

# %%
text = "hello"
result = text.islower()

print(result)  # True
# Out:
# True

# %%
text = "12345"
result = text.isnumeric()

print(result)  # True
# Out:
# True

# %%
text = "Hello World!"
result = text.isprintable()

print(result)  # True
# Out:
# True

# %%
text = "   "
result = text.isspace()

print(result)  # True
# Out:
# True

# %%
text = "Hello World"
result = text.istitle()

print(result)  # True
# Out:
# True

# %%
text = "HELLO"
result = text.isupper()

print(result)  # True
# Out:
# True
