# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanupanchal26/VLAUE_ADDED-COURSE/blob/main/NOTES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. NumPy (Numerical Python)
#
# Purpose: Efficient numerical computations, especially with arrays and matrices.
#
# ------------------
#
# # Why we need it:
#
# Python lists are slow for math operations on large data. NumPy provides arrays that are fast, memory-efficient, and support vectorized operations (do many calculations at once).
#
# ----------------------------
#
# # Key feature:
#
# Multi-dimensional arrays (ndarray)
# Fast math operations like addition, multiplication, mean, sum, etc.
#
#
# ----------------------------------
# | Library   | Category           | Function / Command           | Description / Formula       |
# | --------- | ------------------ | ---------------------------- | --------------------------- |
# | **NumPy** | Array Creation     | `np.array([1,2,3])`          | Create 1D array             |
# |           |                    | `np.array([[1,2],[3,4]])`    | Create 2D array             |
# |           |                    | `np.zeros(5)`                | Array of zeros              |
# |           |                    | `np.ones(3)`                 | Array of ones               |
# |           |                    | `np.arange(0,10,2)`          | Array from 0 to 10 step 2   |
# |           |                    | `np.linspace(0,1,5)`         | 5 numbers evenly spaced 0–1 |
# |           | Math Ops           | `a + b, a - b, a * b, a / b` | Element-wise arithmetic     |
# |           |                    | `a ** 2, np.sqrt(a)`         | Square, square root         |
# |           | Aggregation        | `np.sum(arr)`                | Sum of array                |
# |           |                    | `np.mean(arr)`               | Mean                        |
# |           |                    | `np.median(arr)`             | Median                      |
# |           |                    | `np.std(arr)`                | Standard deviation          |
# |           |                    | `np.var(arr)`                | Variance                    |
# |           |                    | `np.min(arr), np.max(arr)`   | Min / Max                   |
# |           | Linear Algebra     | `np.dot(A,B)`                | Matrix multiplication       |
# |           |                    | `np.transpose(A)`            | Transpose                   |
# |           |                    | `np.linalg.inv(A)`           | Inverse of matrix           |
# |           |                    | `np.linalg.det(A)`           | Determinant                 |
# |           | Random Numbers     | `np.random.rand(3)`          | Random numbers 0–1          |
# |           |                    | `np.random.randint(0,10,5)`  | Random integers 0–9         |
# |           |                    | `np.random.normal(0,1,5)`    | Normal distribution samples |
# |           | Indexing / Slicing | `arr[0], arr[-1]`            | Access elements             |
# |           |                    | `arr[1:4], arr[arr>5]`       | Slice or conditional filter |

# %% [markdown]
# # 2. Pandas
#
# Purpose: Efficient numerical computations, especially with arrays and matrices.
#
# ------------------------------
#
# # Why we need it:
#
# Python lists are slow for math operations on large data. Pandas provides arrays that are fast, memory-efficient, and support vectorized operations (do many calculations at once).
#
# ---------------------
# # Key feature:
#
# Multi-dimensional arrays (ndarray)
# Fast math operations like addition, multiplication, mean, sum, etc.
#
# ------------------------------
#
# | Library    | Category            | Function / Command                               | Description / Formula      |
# | ---------- | ------------------- | ------------------------------------------------ | -------------------------- |
# | **Pandas** | Data Structure      | `pd.Series([1,2,3])`                             | Create Series (1 column)   |
# |            |                     | `pd.DataFrame(data)`                             | Create DataFrame (table)   |
# |            | View Data           | `df.head(), df.tail()`                           | Show first/last rows       |
# |            | Indexing            | `df['col']`                                      | Access column              |
# |            |                     | `df.loc[row_index, col_name]`                    | Label-based row/col access |
# |            |                     | `df.iloc[row_index, col_index]`                  | Position-based access      |
# |            | Aggregation         | `df.sum(), df.mean(), df.median(), df.count()`   | Summarize data             |
# |            | Cleaning            | `df.dropna(), df.fillna(value), df.replace(a,b)` | Handle missing / replace   |
# |            | Sorting / Filtering | `df.sort_values('col')`                          | Sort by column             |
# |            |                     | `df[df['col'] > 10]`                             | Filter rows                |
# |            | Combining           | `pd.concat([df1, df2])`                          | Concatenate DataFrames     |
# |            |                     | `pd.merge(df1, df2, on='key')`                   | Merge / join               |
# |            | Descriptive Stats   | `df.describe()`                                  | Summary statistics         |

# %% [markdown]
# # 3. Matplotlib
#
# Purpose: Create visualizations like graphs and charts.
#
# -------------------------
#
# # Why we need it:
#
# Numbers are boring without visuals. Matplotlib is the foundation for plotting in Python. You can create line plots, bar charts, histograms, scatter plots, etc.
#
# -------------------------
# # Key feature:
# Very customizable
# Base for other libraries like Seaborn
#
# ----------------------------------
#
# | Library        | Category        | Function / Command                   | Description / Formula |
# | -------------- | --------------- | ------------------------------------ | --------------------- |
# | **Matplotlib** | Basic Plots     | `plt.plot(x, y)`                     | Line chart            |
# |                |                 | `plt.scatter(x, y)`                  | Scatter plot          |
# |                |                 | `plt.bar(x, y)`                      | Bar chart             |
# |                |                 | `plt.hist(data, bins=n)`             | Histogram             |
# |                |                 | `plt.pie(data, labels=labels)`       | Pie chart             |
# |                | Labels & Titles | `plt.xlabel('X')`, `plt.ylabel('Y')` | Add axis labels       |
# |                |                 | `plt.title('Title')`                 | Add title             |
# |                | Show / Save     | `plt.show()`                         | Display plot          |
# |                |                 | `plt.savefig('file.png')`            | Save figure           |

# %% [markdown]
# # 4. Seaborn
#
# Purpose: Make beautiful and complex plots easily using pandas data.
#
# ---------------------------
#
# # Why we need it:
# Matplotlib can do everything, but Seaborn makes complex plots simple, especially for statistics. Example: violin plots, heatmaps, pairplots. Works directly with pandas DataFrame.
#
# -------------------------
# # Key feature:
# Stylish default themes
# Easy for data exploration
#
# -----------------------------------------------
# | Library     | Category             | Function / Command                       | Description / Formula        |
# | ----------- | -------------------- | ---------------------------------------- | ---------------------------- |
# | **Seaborn** | Distribution         | `sns.histplot(data)`                     | Histogram                    |
# |             |                      | `sns.kdeplot(data)`                      | Density / KDE plot           |
# |             | Categorical          | `sns.barplot(x, y)`, `sns.boxplot(x, y)` | Compare categories           |
# |             | Scatter / Regression | `sns.scatterplot(x, y)`                  | Scatter plot                 |
# |             |                      | `sns.regplot(x, y)`                      | Scatter with regression line |
# |             | Heatmap              | `sns.heatmap(df.corr())`                 | Correlation heatmap          |
# |             | Pairwise             | `sns.pairplot(df)`                       | Pairwise relationships       |
# |             | Styling              | `sns.set_style('whitegrid')`             | Set plot style / theme       |

# %% [markdown]
# # **NumPy Interview Questions**
# What is NumPy and why is it used?
#
# -->Fast numerical computation library; supports arrays and vectorized operations.
# Difference between Python list and NumPy array.
# Lists are slow and flexible, arrays are fast and memory-efficient.
#
# -----------------------------
#
# How to create a NumPy array?
#
# -->import numpy as np
# arr = np.array([1, 2, 3])
#
# ------------------------------
# What is vectorization in NumPy?
#
# -->Performing operations on entire arrays without loops (faster than for-loops).
#
# ----------------------------------
#
# How to find mean, median, or standard deviation using NumPy?
#
# -->np.mean(arr)
#
# -->np.median(arr)
#
# -->np.std(arr)

# %% [markdown]
# # **pandas Interview Questions**
#
# What is pandas used for?
#
# -->Handling structured data with rows and columns, like CSV or Excel files.
#
# -----------------------
# Difference between Series and DataFrame.
#
# -->Series → 1D labeled data
#
# -->DataFrame → 2D table with rows & columns
#
# ------------------------------
# How to read a CSV in pandas?
#
# -->import pandas as pd
#
# df = pd.read_csv("data.csv")
#
# -----------------------------------------
# How to handle missing data?
#
# -->df.fillna() → fill missing values
# -->df.dropna() → remove rows with missing values
#
# ------------------------------------------
#
# How to filter rows in pandas?
#
# df[df['Age'] > 25]

# %% [markdown]
# # **Matplotlib Interview Questions**
#
# Why use Matplotlib?
#
# -->For creating visualizations like line plots, scatter plots, bar charts.
#
# ---------------------------------------
# How to plot a simple line graph?
#
# -->import matplotlib.pyplot as plt
# -->plt.plot([1,2,3], [4,5,6])
# -->plt.show()
#
# -------------------------------------
# Difference between plt.plot() and plt.scatter():
#
# -->plot() → continuous line graph
# -->scatter() → points plotted individually
#
# ----------------------------------
# How to add labels and title to a plot?
#
# -->plt.title("My Graph")
#
# -->plt.xlabel("X-axis")
#
# -->plt.ylabel("Y-axis")

# %% [markdown]
# # **Seaborn Interview Questions**
#
# Why use Seaborn instead of Matplotlib?
#
# -->Easier to make attractive statistical plots, works directly with pandas.
#
# ------------------------------------
# Common Seaborn plots?
#
# -->sns.barplot(), sns.boxplot(), sns.heatmap(), sns.pairplot()
#
# -----------------------
#
# How to create a bar plot with Seaborn?
#
# -->import seaborn as sns
# -->sns.barplot(x='Name', y='Age', data=df)
#
# ----------------------------------
# Difference between Seaborn and Matplotlib?
#
# -->Matplotlib → low-level plotting (full control)
# --Seaborn → high-level, prettier, easier for statistical data

# %% [markdown]
# NumPy → Fast math with arrays (better than Python
# lists) ,Calculate numbers, do math
#
# ---------------------
#
#
# pandas → Organize and clean tables (better than raw NumPy for dataframes),Clean, filter, and organize your data
#
# -----------------------
#
#
# Matplotlib → Plot anything (full control, basic but flexible) ,Draw basic graphs from your data
#
# -----------------------------
#
#
# Seaborn → Make beautiful, statistical plots (prettier & easier than Matplotlib) ,Make attractive and complex plots for analysis
#
# ------------------------

# %% [markdown]
# | Library        | Question                                 | Short Answer                                                |
# | -------------- | ---------------------------------------- | ----------------------------------------------------------- |
# | **NumPy**      | What is NumPy?                           | Python library for fast numerical computation using arrays. |
# |                | Why use NumPy over lists?                | Faster, memory-efficient, supports vectorized operations.   |
# |                | What is vectorization?                   | Performing operations on whole arrays without loops.        |
# |                | How to create an array?                  | `np.array([1,2,3])`                                         |
# |                | How to find mean/std?                    | `np.mean(arr)`, `np.std(arr)`                               |
# | **pandas**     | What is pandas?                          | Library for data analysis and manipulation (tables).        |
# |                | Difference between Series & DataFrame?   | Series → 1D; DataFrame → 2D table.                          |
# |                | How to read CSV?                         | `pd.read_csv('file.csv')`                                   |
# |                | How to handle missing data?              | `df.fillna()` or `df.dropna()`                              |
# |                | How to filter rows?                      | `df[df['Age']>25]`                                          |
# | **Matplotlib** | What is Matplotlib?                      | Library for creating basic plots & charts.                  |
# |                | Difference between plot() and scatter()? | plot() → line, scatter() → points.                          |
# |                | How to add title/labels?                 | `plt.title()`, `plt.xlabel()`, `plt.ylabel()`               |
# |                | How to plot multiple lines?              | Use `plt.plot()` multiple times before `plt.show()`         |
# |                | Types of plots?                          | Line, bar, scatter, histogram, pie.                         |
# | **Seaborn**    | What is Seaborn?                         | Library for stylish statistical plots, works with pandas.   |
# |                | Why use Seaborn over Matplotlib?         | Easier & prettier for statistical visualization.            |
# |                | Common plots?                            | barplot, boxplot, violinplot, heatmap, pairplot             |
# |                | How to change theme/style?               | `sns.set_theme(style='darkgrid')`                           |
# |                | How to plot heatmap?                     | `sns.heatmap(data)`                                         |

# %% [markdown]
# # What is a Dashboard?
#
# A Dashboard is a visual display of important data and information in one place using charts, graphs, and tables.
#
# ------------------
#
#
# # Simple Definition
#
# Dashboard = Visual summary of data for quick decision-making

# %% [markdown]
# # Difference Between Microsoft Excel and Google Sheets
#
# ----------------------------------
#
#
#
# | Microsoft Excel              | Google Sheets                |
# | ---------------------------- | ---------------------------- |
# | Desktop software             | Cloud-based (online)         |
# | Works offline                | Works mainly online          |
# | More powerful for large data | Slower with large data       |
# | Advanced formulas & tools    | Basic to moderate tools      |
# | Paid software                | Free (with Google account)   |
# | Harder collaboration         | Easy real-time collaboration |

# %% [markdown]
# # Difference Between Matplotlib and Seaborn
#
# ----------------------------------
# | Matplotlib             | Seaborn                        |
# | ---------------------- | ------------------------------ |
# | Basic plotting library | Advanced visualization library |
# | More coding required   | Less coding required           |
# | Basic charts           | More attractive charts         |
# | More control           | Easier to use                  |
# | Older library          | Built on Matplotlib            |

# %% [markdown]
# # What is NumPy?
#
# NumPy is a library in Python used for numerical calculations and working with arrays.
#
# ----------------------------
#
# # Why NumPy is Used
# Fast Calculations
#
# Performs mathematical operations quickly
#
# Work with Arrays
#
# Handles large sets of numbers easily
#
# -----------------------------------------
#
# Mathematical Functions
#
# Addition
#
# Subtraction
#
# Multiplication
#
# Division
#
# Mean, Median, etc.
#
# -------------------------------
#
# **Used in Data Analytics & Data Science**
#
# Works with:
#
# Pandas
#
# Matplotlib
#
# Seaborn

# %% [markdown]
# # What is Pandas?
#
# Pandas is a powerful data analysis and data manipulation library used in Python.
# It helps users read, clean, analyze, and organize data easily.
#
# -----------------------
# # Main Pandas Data Structures
# 1. Series
#
# One-dimensional data (like a column)
#
# 2. DataFrame
#
# Two-dimensional data (like Excel table)
#
# --------------------------
# **Advantages of Pandas**
#
# Easy to use
#
# Fast processing
#
# Handles large data
#
# Powerful analysis tools
#
# ---------------------------
#
# **Pandas is a Python library used to read, clean, analyze, and manipulate data efficiently.**

# %% [markdown]
# # Why Seaborn & Matplotlib Are Still Needed?
#
# 1. More Control & Customization
#
# Excel & Power BI → Limited customization
#
# Seaborn & Matplotlib → Full control over charts
#
# 2. Handle Very Large Data
#
# Excel slows down with large data
#
# Python (Seaborn & Matplotlib) handles millions of rows easily
#
# 3. Automation
#
# 4. Advanced AnalyticS
#
# 5. Used with Python Data Tools
#
# ---------------------------------
#
# | Excel / Power BI    | Seaborn / Matplotlib     |
# | ------------------- | ------------------------ |
# | Easy to use         | More powerful            |
# | Limited charts      | Advanced charts          |
# | Manual work         | Automation possible      |
# | Small-medium data   | Large data               |
# | Business dashboards | Data science & analytics |

# %% [markdown]
# # Need of Python in Data Analytics
#
# Python is needed in Data Analytics to analyze data, automate tasks, and create insights easily.
#
# -------------------------
#
# Easy to Learn & Use ->
# Python has simple syntax, so beginners can learn quickly.
#
# Handle Large Data->
# Python can analyze big datasets easily.
#
# Powerful Libraries ->Python has special libraries for data analytics:
#
# Pandas → Data analysis
#
# NumPy → Calculations
#
# Matplotlib → Charts & graphs
#
# Seaborn → Advanced visuals
#
# Data Visualization ->
# Python helps create graphs and charts to understand data better.
#
# Automation
#
# Python automates repetitive tasks like:
#
# Cleaning data
#
# Sorting data
#
# Reporting
#
# **Python is used in Data Analytics to analyze data quickly and make smart decisions.**

# %% [markdown]
# # What is Metadata?
#
# Metadata is data about data — it describes or gives information about other data.
#
#
# ----------------
#
# **Simple Definition**
#
# Metadata = Information that explains data
#
# ----------------
#
#
# Real-Life Example--->DOC FILE ,PHOTOS IN GALLRY
#
# In apps like Google Photos or WhatsApp, metadata includes:
#
# Time message sent,
# Sender name,
# File size,
# Location

# %% [markdown]
# # Difference Between Data and Information
#
# | Data                  | Information                   |
# | --------------------- | ----------------------------- |
# | Raw facts and figures | Processed and meaningful data |
# | Unorganized           | Organized and structured      |
# | No meaning by itself  | Has clear meaning             |
# | Used as input         | Used for decision-making      |

# %% [markdown]
# # Why is Data Analytics Needed?
#
# Data Analytics is needed to help businesses and organizations make better decisions using data instead of guessing.
#
# ----------------------------
# Better decision making
#
# Understand customers
#
# Increase profits
#
# Solve business problems
#
# Predict future trends
#
# Improve business performance

# %% [markdown]
# # NUMPY COMMANDS
#
# | Command               | Example                     | Output              |
# | --------------------- | --------------------------- | ------------------- |
# | `np.array()`          | `np.array([1,2,3])`         | `[1 2 3]`           |
# | `np.zeros()`          | `np.zeros((2,2))`           | `[[0. 0.],[0. 0.]]` |
# | `np.ones()`           | `np.ones((2,2))`            | `[[1. 1.],[1. 1.]]` |
# | `np.arange()`         | `np.arange(1,5)`            | `[1 2 3 4]`         |
# | `np.linspace()`       | `np.linspace(1,5,4)`        | `[1 2.33 3.66 5]`   |
# | `np.reshape()`        | `arr.reshape(2,2)`          | reshaped array      |
# | `np.mean()`           | `np.mean([1,2,3])`          | `2.0`               |
# | `np.sum()`            | `np.sum([1,2,3])`           | `6`                 |
# | `np.max()`            | `np.max([1,2,3])`           | `3`                 |
# | `np.min()`            | `np.min([1,2,3])`           | `1`                 |
# | `np.std()`            | `np.std(arr)`               | std value           |
# | `np.random.rand()`    | `np.random.rand(3)`         | random values       |
# | `np.random.randint()` | `np.random.randint(1,10,3)` | random integers     |
# | `np.unique()`         | `np.unique(arr)`            | unique values       |
# | `np.sort()`           | `np.sort(arr)`              | sorted array        |

# %% [markdown]
# # PANDAS COMMANDS
#
# | Command                | Example                   | Output            |
# | ---------------------- | ------------------------- | ----------------- |
# | `pd.read_csv()`        | `pd.read_csv("file.csv")` | dataframe         |
# | `df.head()`            | `df.head()`               | first 5 rows      |
# | `df.tail()`            | `df.tail()`               | last 5 rows       |
# | `df.shape`             | `df.shape`                | (rows, columns)   |
# | `df.columns`           | `df.columns`              | column names      |
# | `df.info()`            | `df.info()`               | info              |
# | `df.describe()`        | `df.describe()`           | summary           |
# | `df.drop()`            | `df.drop("col")`          | remove column     |
# | `df.fillna()`          | `df.fillna(0)`            | fill missing      |
# | `df.isnull()`          | `df.isnull()`             | null values       |
# | `df.groupby()`         | `df.groupby("col")`       | grouped data      |
# | `df.sort_values()`     | `df.sort_values("col")`   | sorted            |
# | `df.drop_duplicates()` | `df.drop_duplicates()`    | remove duplicates |
# | `df.merge()`           | `pd.merge(df1,df2)`       | merged data       |
# | `df.loc[]`             | `df.loc[0]`               | row by label      |
# | `df.iloc[]`            | `df.iloc[0]`              | row by index      |

# %% [markdown]
# # MATPLOTLIB COMMANDS
#
# | Command         | Example                     | Output      |
# | --------------- | --------------------------- | ----------- |
# | `plt.plot()`    | `plt.plot(x,y)`             | line chart  |
# | `plt.bar()`     | `plt.bar(x,y)`              | bar chart   |
# | `plt.scatter()` | `plt.scatter(x,y)`          | scatter     |
# | `plt.hist()`    | `plt.hist(data)`            | histogram   |
# | `plt.pie()`     | `plt.pie(data)`             | pie chart   |
# | `plt.title()`   | `plt.title("chart")`        | title       |
# | `plt.xlabel()`  | `plt.xlabel("x")`           | x label     |
# | `plt.ylabel()`  | `plt.ylabel("y")`           | y label     |
# | `plt.legend()`  | `plt.legend()`              | legend      |
# | `plt.figure()`  | `plt.figure(figsize=(5,5))` | figure size |
# | `plt.show()`    | `plt.show()`                | display     |

# %% [markdown]
# # SEABORN COMMANDS
#
#
# | Command             | Example                     | Output       |
# | ------------------- | --------------------------- | ------------ |
# | `sns.countplot()`   | `sns.countplot(x="col")`    | count plot   |
# | `sns.barplot()`     | `sns.barplot(x,y)`          | bar plot     |
# | `sns.scatterplot()` | `sns.scatterplot(x,y)`      | scatter      |
# | `sns.lineplot()`    | `sns.lineplot(x,y)`         | line plot    |
# | `sns.boxplot()`     | `sns.boxplot(x,y)`          | box plot     |
# | `sns.heatmap()`     | `sns.heatmap(data)`         | heatmap      |
# | `sns.pairplot()`    | `sns.pairplot(df)`          | pair plot    |
# | `sns.histplot()`    | `sns.histplot(data)`        | histogram    |
# | `sns.distplot()`    | `sns.distplot(data)`        | distribution |
# | `sns.violinplot()`  | `sns.violinplot(x,y)`       | violin plot  |
# | `sns.set_style()`   | `sns.set_style("darkgrid")` | style        |

# %% [markdown]
# # SQL COMMANDS
#
# | Command    | Example               | Output         |
# | ---------- | --------------------- | -------------- |
# | SELECT     | `SELECT * FROM table` | all rows       |
# | WHERE      | `WHERE age > 25`      | filtered rows  |
# | ORDER BY   | `ORDER BY salary`     | sorted         |
# | GROUP BY   | `GROUP BY dept`       | grouped        |
# | HAVING     | `HAVING COUNT(*)>5`   | filtered group |
# | COUNT()    | `COUNT(*)`            | count          |
# | SUM()      | `SUM(salary)`         | sum            |
# | AVG()      | `AVG(salary)`         | average        |
# | MAX()      | `MAX(salary)`         | max            |
# | MIN()      | `MIN(salary)`         | min            |
# | INNER JOIN | `INNER JOIN table2`   | matched rows   |
# | LEFT JOIN  | `LEFT JOIN table2`    | left rows      |
# | RIGHT JOIN | `RIGHT JOIN table2`   | right rows     |
# | DISTINCT   | `SELECT DISTINCT col` | unique values  |
# | LIMIT      | `LIMIT 5`             | first rows     |
