# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanupanchal26/VLAUE_ADDED-COURSE/blob/main/DATACLEANIG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_excel('/content/1_Retail_Cleaning_Practice.xlsx')
df.head()
# Out:
#   Transaction_ID Customer_Name               Email  Product_Cat  Quantity  \
# 0       TXN-0332     Diana 331   user_331@mail.com         Home         4
# 1       TXN-1005      Bob 1004  user_1004@mail.com      Fashion         2
# 2       TXN-1928      Bob 1927  user_1927@mail.com  Electronics         2
# 3       TXN-0998       Bob 997   user_997@mail.com  Electronics         4
# 4       TXN-1655  Charlie 1654  user_1654@mail.com       Beauty         1
#
#    Unit_Price Store_City Payment_Method         Timestamp
# 0   29.546020      Tokyo    Credit Card  2026-01-14 19:00
# 1   74.074169     Mumbai           Cash  2026-02-11 20:00
# 2   41.254762      Tokyo    Credit Card  2026-03-22 07:00
# 3   67.286899   New York            UPI  2026-02-11 13:00
# 4   55.856927      Tokyo            UPI  2026-03-10 22:00
