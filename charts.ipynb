# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanupanchal26/VLAUE_ADDED-COURSE/blob/main/charts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Bar Chart**
# When to use: Compare categories
#
# X-axis: Categories (e.g., Products, Names)
#
# Y-axis: Values (e.g., Sales, Count)
#
#
# ![horizontal-bar-chart-example-1627292930.webp](data:image/webp;base64,...)

# %% [markdown]
# # **2. Histogram**
#
# When to use: Show distribution of data
#
# X-axis: Value ranges (bins)
#
# Y-axis: Frequency (how many times values occur)
#
# ![Histogram.webp](data:image/webp;base64,...)

# %% [markdown]
# # **3.  Column Chart**
#
# (Same as bar but vertical)
#
# When to use: Compare values across categories
#
# X-axis: Categories
#
# Y-axis: Values
#
# ![47.webp](data:image/webp;base64,...)

# %% [markdown]
# # **4. Line Chart**
#
# When to use: Show trends over time
#
# X-axis: Time (days, months, years)
#
# Y-axis: Values (sales, temperature)
#
# ![mixed-combo-line-column-chart.webp](data:image/webp;base64,...)

# %% [markdown]
# # **5.  Pie Chart**
#
# When to use: Show proportions (%)
#
# X-axis: Not used
#
# Y-axis: Not used
#
# Uses slices instead of axes
#
# ![ed8e678d-f7b7-43f4-ab4d-ce34c6bc4f70.webp](data:image/webp;base64,...)

# %% [markdown]
# # **6.  Donut Chart**
#
# (Same as pie, just with a hole)
#
# When to use: Show proportions
#
# Axes: Not used
#
# ![donut-chart-main-1.webp](data:image/webp;base64,...)

# %% [markdown]
# # **7.  Stacked Bar Chart**
#
# When to use: Compare totals + parts
#
# X-axis: Categories
#
# Y-axis: Total value (with segments inside)
#
# ![StackedBarChart_TeachingExample.webp](data:image/webp;base64,...)

# %% [markdown]
# # **8. Scatter Plot**
#
# When to use: Show relationship between 2 variables
#
# X-axis: Variable 1 (e.g., Age)
#
# Y-axis: Variable 2 (e.g., Salary)
#
# ![scatter-plot-options-2.webp](data:image/webp;base64,...)

# %% [markdown]
# # **9.  Area Chart**
#
# When to use: Show trends + volume
#
# X-axis: Time
#
# Y-axis: Values
#
# ![area-chart-mian.webp](data:image/webp;base64,...)

# %% [markdown]
# # **10.  Step Chart**
#
# When to use: Show changes at specific points
#
# X-axis: Time or steps
#
# Y-axis: Values
#
# ![StepChart.webp](data:image/webp;base64,...)

# %% [markdown]
# # **11. Geo Chart**
#
# When to use: Show data on map
#
# X-axis: Location (country, state)
#
# Y-axis: Values (population, sales)
#
# ![geo-chart-light.webp](data:image/webp;base64,...)

# %% [markdown]
# # **12.  Heatmap**
#
# When to use: Show intensity using colors
#
# X-axis: Variable 1
#
# Y-axis: Variable 2
#
# Color: Value strength
#
# ![Mouse-Heatmap-VWO-Example-1024x652.png.webp](data:image/webp;base64,...)

# %% [markdown]
# # **13. Box Plot (Whisker Plot)**
#
# A box plot is used to show how your data is spread (distribution).
# It helps you quickly see:
#
# Middle value
#
# Spread of data
#
# Outliers (unusual values)
#
# X-axis: Categories
#
# Y-axis: Values (distribution)
#
# ![boxplot4.webp](data:image/webp;base64,...)
