# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanupanchal26/VLAUE_ADDED-COURSE/blob/main/Task_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![picture.png](data:image/png;base64,...)

# %% [markdown]
# # 1. Data Collection 📥
#
# Definition:
# Data collection is the process of gathering raw data from different sources.
#
# -----------------
#
#
# **Sources of Data:**
#
# Databases
#
# APIs
#
# Sensors
#
# Surveys
#
# Websites
#
# Excel files
#
# --------------
#
# **Example:**
#
# Collecting customer data from an online shopping website.
#
# -----------------------------
#
# **Importance:**
#
# First step in data science

# %% [markdown]
# # 2. Data Warehouse 🏢
#
# Definition:
# A Data Warehouse is a centralized system used to store large amounts of structured data.
#
# ------------------------------------
#
# **Features:**
#
# Centralized storage
#
# Historical data
#
# Fast querying
#
# ----------------------------
#
# **Example:**
#
# Company stores sales data of last 10 years in data warehouse.
#
# -----------------------------------------------
#
# **Benefits:**
#
# Easy reporting
# Business intelligence
# Data analysis

# %% [markdown]
# # 3. Data Cleaning 🧹
#
# Definition:
# Data cleaning is the process of removing incorrect, duplicate, and missing data.
#
# -----------------------------
#
# **Tasks in Data Cleaning:**
#
# Remove duplicates
#
# Fix missing values
#
# Correct errors
#
# Remove outliers
#
# ----------------------------------
#
# **Example:**
# Age = 200 → Incorrect → Remove or fix

# %% [markdown]
# # 4. Data Transformation 🔄
#
# **Definition:**
# Data transformation converts data into a suitable format for analysis.
#
# -----------------------
#
# **Types:**
#
# Normalization
#
# Scaling
#
# Formatting
#
# Encoding
#
# --------------------------------------------
#
# **Example:**
# Date format:
# 01-01-2024 → 2024-01-01

# %% [markdown]
# # 5. Data Reduction 📉
#
# Definition:
# Reducing the size of data while keeping important information.
#
# --------------------------
#
# **Methods:**
#
# Sampling
#
# Aggregation
#
# Feature selection
#
# ------------------------------------
#
# **Example:**
# Using 10,000 rows instead of 1 million rows.
#
# ----------------------------------
#
# **Benefits:**
#
# Faster processing
#
# Less storage

# %% [markdown]
# # 6. Data Integration 🔗
#
# Definition:
# Combining data from multiple sources into one dataset.
#
# ---------------------------
#
# **Example:**
#
# Customer data from CRM
#
# Sales data from database
#
# Combine both.
#
#
# ---------------------------
#
# **Benefits:**
#
# Better insights
#
# Unified data

# %% [markdown]
# # 7. Data Imputation 🧩
#
# Definition:
# Filling missing values in dataset.
#
# ---------------------
#
# **Methods:**
#
# Mean
#
# Median
#
# Mode
#
# Machine Learning
#
# ----------------------------
#
# **Example:**
# Age column missing → fill with average age

# %% [markdown]
# # 8. Data Encoding 🔢
#
# Definition:
# Converting categorical data into numeric values.
# ------------------------
#
# **Types:**
#
# Label Encoding
#
# One-Hot Encoding
#
# --------------------
#
# **Example:**
#
# Gender:
#
# Male = 0
# Female = 1

# %% [markdown]
# # 9. Data Munging 🔧
#
# Definition:
# Cleaning and transforming raw data into structured format.
#
# --------------------------
#
# **Also called:**
#
# Data Munging = Data Wrangling
#
# -----------------------------
#
# **Tasks:**
#
# Cleaning
#
# Formatting
#
# Filtering

# %% [markdown]
# # 10. Data Wrangling 🧰
#
# Definition:
# Preparing raw data for analysis.
#
# ---------------------------
#
# **Steps:**
#
# Cleaning
#
# Transforming
#
# Structuring
#
# --------------------------------------------
#
# **Example**:
# Converting messy Excel file into structured dataset.

# %% [markdown]
# # 11. Data Scraping 🌐
#
# Definition:
# Extracting data from websites automatically.
#
# --------------------
#
# **Tools:**
#
# Python
#
# BeautifulSoup
#
# Selenium
#
# -------------------
#
# **Example**:
# Scraping product prices from Amazon.

# %% [markdown]
# # 12. Data Aggregation 📊
#
# Definition:
# Summarizing data using mathematical operations.
#
# -------------------------------------
#
# **Operations**:
#
# Sum
#
# Average
#
# Count
#
# Min
#
# Max
#
#
# --------
#
# **Example**:
# Total sales per month

# %% [markdown]
# # 13. Data Visualization 📈
#
# Definition:
# Representing data using charts and graphs.
#
# -------------------
#
# **Types**:
#
# Bar Chart
#
# Pie Chart
#
# Line Chart
#
# Histogram
#
# --------------------
#
# **Benefits**:
#
# Easy understanding
#
# Better decision making

# %% [markdown]
# # 14. Machine Learning 🤖
#
# Definition:
# Machine Learning is a method where machines learn from data and make predictions.
#
# -----------------------
#
# **Types**:
#
# Supervised Learning
#
# Unsupervised Learning
#
# Reinforcement Learning
#
# ---------------
#
# **Example**:
# Predicting house prices.

# %% [markdown]
# # 15. Artificial Intelligence 🧠
#
# Definition:
# Artificial Intelligence is simulation of human intelligence in machines.
#
# --------------------------------
#
# **Examples**:
#
# Chatbots
#
# Self-driving cars
#
# Voice assistants

# %% [markdown]
# # 16. Data Summarization 📄
#
# Definition:
# Providing a summary of data.
#
# -----------
#
# **Methods**:
#
# Mean
#
# Median
#
# Mode
#
# Standard deviation
#
# ------------
#
# **Example**:
# Average salary of employees.

# %% [markdown]
# # 17. Data Generalization 📚
#
# Definition:
# Reducing detailed data into categories.
#
# -------------------------
#
# **Example**:
#
# Age:
#
# 0–18 → Young'
#
# 18–60 → Adult
#
# 60+ → Senior

# %% [markdown]
# # 18. Data Mining ⛏️
#
# Definition:
# Extracting useful patterns from large datasets.
#
# -----------------------
#
# **Techniques**:
#
# Clustering
#
# Classification
#
# Association rules
#
# ---------
#
# **Example**:
# Customers who buy milk also buy bread.

# %% [markdown]
# # 19. Meta Data 🏷️
#
# Definition:
# Data about data.
#
# ------------------
#
# **Examples**:
#
# File size
#
# Author
#
# Date created
#
# File type

# %% [markdown]
# # 20. Data Factorization 🔢
#
# Definition:
# Converting categorical variables into numeric codes.
#
# ----------------
#
# **Example**:
#
# City:
#
# Ahmedabad = 0
#
# Mumbai = 1
#
# Delhi = 2

# %% [markdown]
# # 21. Data Vectorization 📐
#
# Definition:
# Converting data (especially text) into numerical vectors.
#
# -------------------
#
# **Used in:**
#
# Machine learning
#
# NLP (Natural Language Processing)
#
#
# --------------
#
# **Example**:
# Text:
# "Hello World" → [0.25, 0.78, 0.66]
